# %%
import sys
import os
import warnings

sys.path.append(os.path.abspath('../script'))
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
from scrape import Scraper
from clean_data import DataCleaner
from sentiment_analysis import SentimentAnalysis
import pandas as pd

# %%
scrape = Scraper()

# %%
datasets = pd.DataFrame()
for key, value in scrape.BANK_APPS.items():
    df = scrape.scrape_bank_reviews(value, key)
    datasets = pd.concat([datasets, df], ignore_index=True)

# %%
datasets = datasets.drop_duplicates(subset=None, keep='first', inplace=False)
datasets.duplicated().sum()
# Out:
# np.int64(0)

# %%
datasets.to_csv("../data/reviews_dataset.csv", index=False)

# %% [markdown]
# ### task two

# %%
datasets.sample(10)
# Out:
#                               bank                                review  \
# 462    Commercial Bank of Ethiopia      this APK Best for most of people
# 2374   Commercial Bank of Ethiopia                     Baayyee gaariidha
# 2076   Commercial Bank of Ethiopia   Best mobile banking app in Ethiopia
# 954    Commercial Bank of Ethiopia                                  جميل
# 10064                  Dashen Bank  oh nice!!! i wish it's very nice app
# 297    Commercial Bank of Ethiopia                       I like this app
# 4041   Commercial Bank of Ethiopia                                     ❤
# 8428             Bank of Abyssinia                          አይሰራም ሼም ነው፤
# 509    Commercial Bank of Ethiopia                                  good
# 49     Commercial Bank of Ethiopia                                    Ok
#
#        rating        date
# 462         5  2025-08-13
# 2374        5  2024-10-19
# 2076        5  2024-12-20
# 954         5  2025-04-11
# 10064       5  2025-01-14
# ...

# %%
cleaner = DataCleaner()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/dawitabraham/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/dawitabraham/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
datasets['Cleaned_Review'] = datasets['review'].apply(
    lambda x: cleaner.clean_text(x)
)

# %% [markdown]
# ### Sentiment Analysis
