# %%
import sys
import os
import warnings

sys.path.append(os.path.abspath('../script'))
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
from scrape import Scraper
import pandas as pd

# %%
scrape = Scraper()

# %%
datasets = pd.DataFrame()
for key, value in scrape.BANK_APPS.items():
    df = scrape.scrape_bank_reviews(value, key)
    datasets = pd.concat([datasets, df], ignore_index=True)

# %%
datasets = datasets.drop_duplicates(subset=None, keep='first', inplace=False)
datasets.duplicated().sum()
# Out:
# np.int64(0)

# %%
datasets.sample(10)
# Out:
#                              bank  \
# 1264  Commercial Bank of Ethiopia
# 7890  Commercial Bank of Ethiopia
# 9662                  Dashen Bank
# 7554  Commercial Bank of Ethiopia
# 8779            Bank of Abyssinia
# 3022  Commercial Bank of Ethiopia
# 4923  Commercial Bank of Ethiopia
# 3618  Commercial Bank of Ethiopia
# 4377  Commercial Bank of Ethiopia
# 8268            Bank of Abyssinia
#
#                                                  review  rating        date
# 1264                                      Excellent app       5  2025-03-12
# 7890                                               Good       5  2018-10-17
# 9662                                   nice application       5  2025-05-27
# 7554  The app is not compatible with certain devices...       2  2020-08-25
# 8779  Please fix the app i doesn't belongs to Abbssi...       1  2024-05-22
# 3022                                               Good       5  2024-06-26
# 4923                                                 He       4  2023-09-10
# 3618                                      It's nice app       5  2024-03-09
# 4377                                          It's Good       5  2023-12-21
# 8268                                               goof       5  2025-06-25

# %%
datasets.to_csv("../data/reviews_dataset.csv", index=False)
