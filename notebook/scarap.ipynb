# %%
import sys
import os
import warnings

sys.path.append(os.path.abspath('../script'))
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
from scrape import Scraper
import pandas as pd

# %%
scrape = Scraper()

# %%
dataset = pd.DataFrame
for key, value in scrape.BANK_APPS.items():
    df = scrape.scrape_bank_reviews(value, key)
    dataset.concat(df)

print(dataset.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 4
#       2 for key, value in scrape.BANK_APPS.items():
#       3     df = scrape.scrape_bank_reviews(value, key)
# ----> 4     dataset.concat(df)
#       6 print(dataset.head())
#
# AttributeError: type object 'DataFrame' has no attribute 'concat'
